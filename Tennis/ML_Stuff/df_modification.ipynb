# %%
import pandas as pd

# %%
#df_1 = pd.read_csv(r"C:\Users\Carlo\Repos\TrainingsTool\Tennis\exported_results\incomplete_but_close_enough.csv", encoding="unicode_escape", low_memory=False)
#df_1 = pd.read_csv(r"C:\Users\Carlo\Repos\TrainingsTool\Tennis\exported_results\mcts_random_uct_vs_djoko_40_60.csv", encoding='unicode_escape', low_memory=False)
#df_2 = pd.read_csv(r"C:\Users\Carlo\Repos\TrainingsTool\Tennis\exported_results\mcts_random_uct_vs_djoko_32_73.csv", encoding='unicode_escape', low_memory=False)

df_1 = pd.read_csv(r"C:\Users\Carlo\Repos\TrainingsTool\Tennis\exported_results\mcts_random_greedy_vs_djoko_43_57.csv", encoding='unicode_escape', low_memory=False)
df_2 = pd.read_csv(r"C:\Users\Carlo\Repos\TrainingsTool\Tennis\exported_results\mcts_random_greedy_vs_djoko_35_65.csv", encoding='unicode_escape', low_memory=False)

# %%
df_1
# Out:
#        Points_A  Points_B  Games_A  Games_B  Sets_A  Sets_B  Serving_Player  \
# 0             0        15        0        0       0       0               1
# 1            15        15        0        0       0       0               1
# 2            15        30        0        0       0       0               1
# 3            30        30        0        0       0       0               1
# 4            40        30        0        0       0       0               1
# ...         ...       ...      ...      ...     ...     ...             ...
# 15898         0         0        5        2       1       1               1
# 15899        15         0        5        2       1       1               1
# 15900        30         0        5        2       1       1               1
# 15901        40         0        5        2       1       1               1
# 15902         0         0        0        0       0       0               2
#
#                                                   Ralley
# ...

# %%
df_1
# Out:
#        Points_A  Points_B  Games_A  Games_B  Sets_A  Sets_B  Serving_Player  \
# 0             0        15        0        0       0       0               1
# 1            15        15        0        0       0       0               1
# 2            15        30        0        0       0       0               1
# 3            30        30        0        0       0       0               1
# 4            40        30        0        0       0       0               1
# ...         ...       ...      ...      ...     ...     ...             ...
# 15898         0         0        5        2       1       1               1
# 15899        15         0        5        2       1       1               1
# 15900        30         0        5        2       1       1               1
# 15901        40         0        5        2       1       1               1
# 15902         0         0        0        0       0       0               2
#
#                                                   Ralley
# ...

# %%
selected_rows_df_2 = df_2.iloc[464:, :]
selected_rows_df_2
# Out:
#        Points_A  Points_B  Games_A  Games_B  Sets_A  Sets_B  Serving_Player  \
# 464           0        15        0        0       0       0               2
# 465          15        15        0        0       0       0               2
# 466          15        30        0        0       0       0               2
# 467          15        40        0        0       0       0               2
# 468          30        40        0        0       0       0               2
# ...         ...       ...      ...      ...     ...     ...             ...
# 16907        15         0        5        4       1       1               1
# 16908        30         0        5        4       1       1               1
# 16909        30        15        5        4       1       1               1
# 16910        40        15        5        4       1       1               1
# 16911         0         0        0        0       0       0               2
#
#                                                   Ralley
# ...

# %%
df_new = pd.concat([df_1, selected_rows_df_2], ignore_index=True)

# %%
df_new
# Out:
#        Points_A  Points_B  Games_A  Games_B  Sets_A  Sets_B  Serving_Player  \
# 0             0        15        0        0       0       0               1
# 1            15        15        0        0       0       0               1
# 2            15        30        0        0       0       0               1
# 3            30        30        0        0       0       0               1
# 4            40        30        0        0       0       0               1
# ...         ...       ...      ...      ...     ...     ...             ...
# 32346        15         0        5        4       1       1               1
# 32347        30         0        5        4       1       1               1
# 32348        30        15        5        4       1       1               1
# 32349        40        15        5        4       1       1               1
# 32350         0         0        0        0       0       0               2
#
#                                                   Ralley
# ...

# %%
#df_new.to_csv("mcts_random_greedy_vs_djoko_102_98.csv", index = False)
#df_new.to_csv("mcts_random_uct_vs_djoko_72_128.csv", index = False)
df_new.to_csv("mcts_random_greedy_vs_djoko_78_122.csv", index = False)
