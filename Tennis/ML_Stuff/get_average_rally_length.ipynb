# %%
import pandas as pd
import ast

# %%
df = pd.read_csv(r"C:\Users\Carlo\Repos\TrainingsTool\Tennis\exported_results\parameter_adaptations\mcts_uct_greedy_w2-05_10_vs_average_64_36.csv", encoding='unicode_escape', low_memory=False)
df
# Out:
#        Points_A  Points_B  Games_A  Games_B  Sets_A  Sets_B  Serving_Player  \
# 0            15         0        0        0       0       0               1
# 1            15        15        0        0       0       0               1
# 2            30        15        0        0       0       0               1
# 3            40        15        0        0       0       0               1
# 4            40        30        0        0       0       0               1
# ...         ...       ...      ...      ...     ...     ...             ...
# 16364        15         0        6        5       1       0               1
# 16365        15        15        6        5       1       0               1
# 16366        30        15        6        5       1       0               1
# 16367        40        15        6        5       1       0               1
# 16368         0         0        0        0       0       0               2
#
#                                                   Ralley
# ...

# %%
df_test = df
df_test
# Out:
#        Points_A  Points_B  Games_A  Games_B  Sets_A  Sets_B  Serving_Player  \
# 0            15         0        0        0       0       0               1
# 1            15        15        0        0       0       0               1
# 2            30        15        0        0       0       0               1
# 3            40        15        0        0       0       0               1
# 4            40        30        0        0       0       0               1
# ...         ...       ...      ...      ...     ...     ...             ...
# 16364        15         0        6        5       1       0               1
# 16365        15        15        6        5       1       0               1
# 16366        30        15        6        5       1       0               1
# 16367        40        15        6        5       1       0               1
# 16368         0         0        0        0       0       0               2
#
#                                                   Ralley
# ...

# %%
# Convert string representations of lists to actual lists
df_test['Ralley'] = df_test['Ralley'].apply(ast.literal_eval)

# Calculate the length of each array
array_lengths = df_test['Ralley'].apply(lambda x: len(x) if isinstance(x, list) else 0)

# Calculate the average length
average_length = array_lengths.mean()

print(str(average_length))
# Out:
# 5.027918626672369
